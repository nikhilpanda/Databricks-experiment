# %%
# %sql
select 'Hello World!'

# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3
#
# Ordered list
# 1. Coffee
# 2. Tea
# 3. Expresso
#
# My name is **Nikhil Panda** and I am *26* years *old*
#
# Unordered list
# * Bhubaneswar
# * Hyderabad
# * Banglore

# %%
# %fs ls '/Workspace/Users/nikhilpanda26@gmail.com/Databricks-Certified-Data-Engineer-Associate'

# %%
# %run ./experiment

# %%
print(f'My name is {name}')

# %%
# %sql
CREATE TABLE EMPLOYEES (
    id INT,
    name varchar(256),
    salary bigint
)

# %%
# %sql 
INSERT INTO EMPLOYEES (id, name, salary) VALUES
(1, 'Ananya Rao', 85000),
(2, 'Rohan Mehta', 92000),
(3, 'Priya Nair', 78000);

INSERT INTO employees(id, name, salary) VALUES
(4, 'Karan Malhotra', 105000),
(5, 'Sneha Iyer', 67000),
(6, 'Arjun Kapoor', 120000),
(7, 'Divya Menon', 73000),
(8, 'Vikram Singh', 98000);

INSERT INTO workspace.default.employees(id, name, salary) VALUES
(9, 'Neha Joshi', 81000),
(10, 'Aditya Verma', 110000);

# %%
# %sql
select * from employees;

# %%
# %sql
DESCRIBE DETAIL EMPLOYEES

# %%
# %sql
DESCRIBE EXTENDED employees

# %%
# %sql
UPDATE employees
SET salary = salary + 5000
WHERE name ILIKE '%Neha%' OR name ILIKE '%Aditya%';

# %%
# %sql
select * from employees;

# %%
# %sql
DESCRIBE DETAIL employees

# %%
# %sql
DESCRIBE HISTORY employees

# %%
# %sql
-- time travel feature
-- select * from employees version as of 5  
select * from employees timestamp as of "2026-07-10T16:35:04.000+00:00";

# %%
# %sql
select * from employees@v4;

# %%
# %sql
DELETE from employees

# %%
# %sql
RESTORE TABLE employees to version as of 4;

# %%
# %sql
select * from employees

# %%
# %sql
OPTIMIZE employees
zorder by id;

# %%
# %sql DESCRIBE DETAIL employees

# %%
# %sql DESCRIBE HISTORY employees
